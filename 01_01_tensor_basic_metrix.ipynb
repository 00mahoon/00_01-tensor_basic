# %%
import tensorflow as tf

# %%
## matrix 선언 하기.
matrix_A = tf.constant([[2,2,4],[1,1,6],[1,3,8]])# 작성
matrix_B = tf.constant([[4,3,3],[2,1,6],[1,2,8]]) # 작성

## matrix 연산하기.
result = tf.matmul(matrix_A,matrix_B) # 작성

## 결과
print("result = {}".format(result))
# Out:
# result = [[16 16 50]
#  [12 16 57]
#  [18 22 85]]
